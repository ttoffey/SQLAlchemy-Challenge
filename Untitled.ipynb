# %%
import pandas as pd
import matplotlib
from matplotlib import style
style.use("seaborn")
import matplotlib.pyplot as plt

# %%
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func

import datetime

# %%
engine=create_engine("sqlite:///./Resources/hawaii.sqlite", echo=False)

# %%
inspector=inspect(engine)
inspector.get_table_names()
# Out:
# ['measurement', 'station']

# %%
columns=inspector.get_columns('measurement')
for col in columns:
    print(col['name'], col['type'])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
columns=inspector.get_columns('station')
for col in columns:
    print(col['name'], col['type'])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
results = engine.execute ("SELECT * FROM measurement LIMIT 10").fetchall()
for r in results:
    print(r)
# Out:
# (1, 'USC00519397', '2010-01-01', 0.08, 65.0)
# (2, 'USC00519397', '2010-01-02', 0.0, 63.0)
# (3, 'USC00519397', '2010-01-03', 0.0, 74.0)
# (4, 'USC00519397', '2010-01-04', 0.0, 76.0)
# (5, 'USC00519397', '2010-01-06', None, 73.0)
# (6, 'USC00519397', '2010-01-07', 0.06, 70.0)
# (7, 'USC00519397', '2010-01-08', 0.0, 64.0)
# (8, 'USC00519397', '2010-01-09', 0.0, 68.0)
# (9, 'USC00519397', '2010-01-10', 0.0, 73.0)
# (10, 'USC00519397', '2010-01-11', 0.01, 64.0)

# %%
Base=automap_base()
Base.prepare(engine,reflect=True)
Measurements=Base.classes.measurement
Stations=Base.classes.station

# %%
session=Session(engine)

# %%
results = session.query(Measurements.id, Measurements.station, Measurements.date, Measurements.prcp, Measurements.tobs).\
    order_by(Measurements.date.desc()).all()
results
# Out:
# [(2724, 'USC00519397', '2017-08-23', 0.0, 81.0),
#  (7635, 'USC00514830', '2017-08-23', 0.0, 82.0),
#  (12187, 'USC00519523', '2017-08-23', 0.08, 82.0),
#  (19550, 'USC00516128', '2017-08-23', 0.45, 76.0),
#  (2723, 'USC00519397', '2017-08-22', 0.0, 82.0),
#  (12186, 'USC00519523', '2017-08-22', 0.0, 82.0),
#  (19549, 'USC00516128', '2017-08-22', 0.5, 76.0),
#  (2722, 'USC00519397', '2017-08-21', 0.0, 81.0),
#  (7634, 'USC00514830', '2017-08-21', 0.02, 79.0),
#  (12185, 'USC00519523', '2017-08-21', None, 82.0),
#  (19548, 'USC00516128', '2017-08-21', 0.56, 76.0),
#  (2721, 'USC00519397', '2017-08-20', 0.0, 81.0),
#  (7633, 'USC00514830', '2017-08-20', 0.01, 80.0),
#  (19547, 'USC00516128', '2017-08-20', None, 78.0),
#  (2720, 'USC00519397', '2017-08-19', 0.0, 79.0),
#  (7632, 'USC00514830', '2017-08-19', 0.0, 80.0),
#  (12184, 'USC00519523', '2017-08-19', None, 85.0),
#  (19546, 'USC00516128', '2017-08-19', 0.09, 71.0),
#  (2719, 'USC00519397', '2017-08-18', 0.0, 80.0),
# ...

# %%
most_recent = [result[2] for result in results]
most_recent = most_recent[0]
most_recent
# Out:
# '2017-08-23'

# %%
compare_date = datetime.datetime.strptime(most_recent, '%Y-%m-%d') - datetime.timedelta(days=365)
compare_date = compare_date.strftime('%Y-%m-%d')
compare_date
# Out:
# '2016-08-23'

# %%
# sel = [Measurements.date, Measurements.prcp]
# yearly_precip = session.query(*sel).\
#     filter(func.strftime("%Y-%m-%d", Measurements.date)>= '2016-08-23').\
#     group_by(Measurements.date).\
#     order_by(Measurements.date.desc()).all()
# yearly_precip

# %%
# sel = [Measurements.date, Measurements.prcp]
# yearly_precip = session.query(*sel).\
#     filter(func.strftime("%Y-%m-%d", Measurements.date).between(compare_date, most_recent).\
#     group_by(Measurements.date).\
#     order_by(Measurements.date.desc())
# #yearly_precip

# %%
sel = [Measurements.date, Measurements.prcp]
yearly_precip = session.query(*sel).\
    filter(Measurements.date <= most_recent).\
    filter(Measurements.date >= compare_date).\
    group_by(Measurements.date).\
    order_by(Measurements.date.desc()).all()
yearly_precip
# Out:
# [('2017-08-23', 0.0),
#  ('2017-08-22', 0.0),
#  ('2017-08-21', 0.0),
#  ('2017-08-20', 0.0),
#  ('2017-08-19', 0.0),
#  ('2017-08-18', 0.0),
#  ('2017-08-17', 0.0),
#  ('2017-08-16', 0.0),
#  ('2017-08-15', 0.02),
#  ('2017-08-14', 0.0),
#  ('2017-08-13', 0.0),
#  ('2017-08-12', 0.0),
#  ('2017-08-11', 0.0),
#  ('2017-08-10', 0.0),
#  ('2017-08-09', 0.0),
#  ('2017-08-08', 0.0),
#  ('2017-08-07', 0.0),
#  ('2017-08-06', 0.0),
#  ('2017-08-05', 0.0),
#  ('2017-08-04', 0.02),
#  ('2017-08-03', 0.0),
#  ('2017-08-02', 0.0),
#  ('2017-08-01', 0.02),
#  ('2017-07-31', 0.0),
#  ('2017-07-30', 0.0),
#  ('2017-07-29', 0.0),
#  ('2017-07-28', 0.0),
#  ('2017-07-27', 0.0),
#  ('2017-07-26', 0.0),
#  ('2017-07-25', 0.0),
#  ('2017-07-24', 0.05),
#  ('2017-07-23', 0.0),
#  ('2017-07-22', 0.03),
#  ('2017-07-21', 0.0),
#  ('2017-07-20', 0.03),
#  ('2017-07-19', 0.0),
#  ('2017-07-18', 0.05),
#  ('2017-07-17', 0.03),
#  ('2017-07-16', 0.02),
#  ('2017-07-15', 0.0),
#  ('2017-07-14', 0.02),
# ...

# %%
selected_dates = [date[0] for date in yearly_precip]
selected_precip = [precip[1] for precip in yearly_precip]

# %%
# selected_dates
# selected_precip

# %%
data={'Date': selected_dates, 'Precipitation': selected_precip}
#data

# %%
df=pd.DataFrame(data)
df.set_index("Date", inplace=True)

# %%
df
# Out:
#             Precipitation
# Date
# 2017-08-23           0.00
# 2017-08-22           0.00
# 2017-08-21           0.00
# 2017-08-20           0.00
# 2017-08-19           0.00
# ...                   ...
# 2016-08-27           0.00
# 2016-08-26           0.00
# 2016-08-25           0.08
# 2016-08-24           0.08
# 2016-08-23           0.00
#
# [366 rows x 1 columns]

# %%
df.iloc[::-1].plot.barh(title="Precipiation - Last Year")
plt.tight_layout()
plt.show()
